# %%
# AMAZON – Object Area

# Object dimensions (in pixels)
width = 60
height = 30

# Calculate area
area = width * height

# Output
print("Output:", area, "px²")
print("Industry: Warehouse Vision")
# Out:
# Output: 1800 px²
# Industry: Warehouse Vision
