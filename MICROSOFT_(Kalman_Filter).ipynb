# %%
# MICROSOFT – Kalman Filter

# Given values
prediction = 20
measurement = 24

# Calculate estimate
estimate = (prediction + measurement) / 2

# Output
print("Output:", int(estimate))
# Out:
# Output: 22
